# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Student_Grade.csv")
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.sample(3)
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 438  CS-97439     A-      D      A        B+      B      A     B+      B
# 523  CS-97524     B-      D      A        A-     B-      A      B      D
# 239  CS-97240      A     B+      A        A+     A-     A+     A-      A
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 438     A-  ...     B+      C     B+      B     B+     C+      B     A-
# 523     B+  ...      B     B-      A      C     D+      B      B     C-
# 239     A-  ...      B     A-      B     B-     A-      A      B     B+
#
#     CS-412   CGPA
# 438     B+  3.219
# 523     C+  2.328
# 239      A  3.573
#
# [3 rows x 43 columns]

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %% [markdown]
# All Datatypes are correct and independent variables need to be encoded

# %%
df.info
# Out:
# <bound method DataFrame.info of      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
# ...

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %% [markdown]
# Checking Target Variable

# %%
df['CGPA'].unique()
# Out:
# array([2.205, 2.008, 3.608, 1.906, 3.448, 3.026, 2.957, 3.043, 3.358,
#        3.247, 2.681, 3.281, 2.792, 3.523, 3.443, 2.777, 3.248, 1.787,
#        3.572, 3.483, 2.246, 2.956, 2.953, 3.586, 3.475, 2.228, 3.44 ,
#        2.188, 3.195, 2.294, 3.133, 3.22 , 3.112, 3.16 , 3.019, 3.164,
#        3.332, 2.165, 3.7  , 3.033, 2.696, 2.851, 3.058, 1.493, 2.069,
#        1.996, 3.897, 3.848, 3.404, 2.254, 2.655, 3.106, 2.793, 3.023,
#        3.01 , 3.4  , 1.899, 3.168, 2.57 , 2.418, 2.564, 2.468, 3.769,
#        2.999, 2.768, 2.822, 3.189, 2.715, 3.578, 3.49 , 2.805, 3.458,
#        2.34 , 3.252, 2.683, 3.378, 3.295, 3.193, 3.647, 2.815, 2.171,
#        3.761, 2.763, 2.938, 2.06 , 1.261, 2.378, 2.861, 2.363, 2.084,
#        1.38 , 1.89 , 3.861, 1.805, 3.925, 3.919, 3.258, 3.963, 2.396,
#        3.772, 1.768, 3.176, 3.335, 3.758, 3.208, 1.845, 3.946, 2.3  ,
#        3.759, 3.516, 2.087, 3.137, 2.011, 2.566, 1.993, 3.334, 2.056,
# ...

# %%
df['CGPA'].nunique()
# Out:
# 491

# %% [markdown]
# *Observation Target Variable shows this is Regression Problem

# %% [markdown]
# # Data Vizualization

# %% [markdown]
# Checking Null Values

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# Treating Null Values as all are categorical data so simpleimputer technique applied

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="most_frequent")
df['CY-105']=imp.fit_transform(df['CY-105'].values.reshape(-1,1))
df['HS-105/12']=imp.fit_transform(df['HS-105/12'].values.reshape(-1,1))
df['MT-111']=imp.fit_transform(df['MT-111'].values.reshape(-1,1))
df['CS-106']=imp.fit_transform(df['CS-106'].values.reshape(-1,1))
df['EL-102']=imp.fit_transform(df['EL-102'].values.reshape(-1,1))
df['EE-119']=imp.fit_transform(df['EE-119'].values.reshape(-1,1))
df['ME-107']=imp.fit_transform(df['ME-107'].values.reshape(-1,1))
df['CS-107']=imp.fit_transform(df['CS-107'].values.reshape(-1,1))
df['HS-205/20']=imp.fit_transform(df['HS-205/20'].values.reshape(-1,1))
df['MT-222']=imp.fit_transform(df['MT-222'].values.reshape(-1,1))
df['EE-222']=imp.fit_transform(df['EE-222'].values.reshape(-1,1))
df['MT-224']=imp.fit_transform(df['MT-224'].values.reshape(-1,1))
df['CS-210']=imp.fit_transform(df['CS-210'].values.reshape(-1,1))
df['CS-211']=imp.fit_transform(df['CS-211'].values.reshape(-1,1))
df['CS-203']=imp.fit_transform(df['CS-203'].values.reshape(-1,1))
df['CS-214']=imp.fit_transform(df['CS-214'].values.reshape(-1,1))
df['EE-217']=imp.fit_transform(df['EE-217'].values.reshape(-1,1))
df['CS-212']=imp.fit_transform(df['CS-212'].values.reshape(-1,1))
df['CS-215']=imp.fit_transform(df['CS-215'].values.reshape(-1,1))
df['MT-331']=imp.fit_transform(df['MT-331'].values.reshape(-1,1))
df['EF-303']=imp.fit_transform(df['EF-303'].values.reshape(-1,1))
df['HS-304']=imp.fit_transform(df['HS-304'].values.reshape(-1,1))
df['CS-301']=imp.fit_transform(df['CS-301'].values.reshape(-1,1))
df['CS-302']=imp.fit_transform(df['CS-302'].values.reshape(-1,1))
df['TC-383']=imp.fit_transform(df['TC-383'].values.reshape(-1,1))
df['MT-442']=imp.fit_transform(df['MT-442'].values.reshape(-1,1))
df['EL-332']=imp.fit_transform(df['EL-332'].values.reshape(-1,1))
df['CS-318']=imp.fit_transform(df['CS-318'].values.reshape(-1,1))
df['CS-306']=imp.fit_transform(df['CS-306'].values.reshape(-1,1))
df['CS-312']=imp.fit_transform(df['CS-312'].values.reshape(-1,1))
df['CS-317']=imp.fit_transform(df['CS-317'].values.reshape(-1,1))
df['CS-403']=imp.fit_transform(df['CS-403'].values.reshape(-1,1))
df['CS-421']=imp.fit_transform(df['CS-421'].values.reshape(-1,1))
df['CS-406']=imp.fit_transform(df['CS-406'].values.reshape(-1,1))
df['CS-414']=imp.fit_transform(df['CS-414'].values.reshape(-1,1))
df['CS-419']=imp.fit_transform(df['CS-419'].values.reshape(-1,1))
df['CS-423']=imp.fit_transform(df['CS-423'].values.reshape(-1,1))
df['CS-412']=imp.fit_transform(df['CS-412'].values.reshape(-1,1))

# %% [markdown]
# Null Value check after removing null values

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# All null values treated , now no null value is present

# %% [markdown]
# Heatmap of Null Values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we know
#
# Seat No is Ordinal Data (have some relation/sequence) -> Categorical Data
#
# other all independent variable are Nominal Data(No Relation between Data) -> Categorical Data
#
# CGPA is Target Variable which is continuous value .

# %%
#Making DataFrame for Nominal Data

# %%
df_visualization_nominal=df.iloc[:,1:-1].copy()
df_visualization_nominal.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412'],
#       dtype='object')

# %% [markdown]
# Visualization of Nominal Data
#
# For Nominal categorical Data we will use countplot as it will give the frequency of the classes of the columns
#
# Visualization of Ordinal Data
#
# For Ordinal Categorical Data we will use lineplot as it will give the flow of the line of the classes of the columns

# %%
#Making DataFrame for Ordinal Data

# %%
df_visualization_ordinal=df[['Seat No.']].copy()
df_visualization_ordinal.columns
# Out:
# Index(['Seat No.'], dtype='object')

# %% [markdown]
# Visualization for ordinal Data - LinePlot

# %%
sns.catplot(y='Seat No.',data=df_visualization_ordinal)
print(df_visualization_ordinal['Seat No.'].value_counts())
# Out:
# CS-97001    1
# CS-97384    1
# CS-97378    1
# CS-97379    1
# CS-97380    1
#            ..
# CS-97185    1
# CS-97184    1
# CS-97183    1
# CS-97182    1
# CS-97571    1
# Name: Seat No., Length: 571, dtype: int64

# %% [markdown]
# Visualization for Nominal Data - CountPlot

# %%
ax=sns.countplot(x='PH-121',data=df_visualization_nominal)
print(df_visualization_nominal['PH-121'].value_counts())
# Out:
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing
#
# Like Total No of Grade A is 111,Total No of Grade C+ is 31 and so on

# %%
ax=sns.countplot(x='HS-105/12',data=df_visualization_nominal)
print(df_visualization_nominal['HS-105/12'].value_counts())
# Out:
# A     97
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# F      1
# Name: HS-105/12, dtype: int64

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing
#
# Like Total No of Grade A is 97,Total No of Grade B is 57 ,Total No of Grade WU is 2 ,Total No of Grade F is 1 and so on

# %%
ax=sns.countplot(x='EE-119',data=df_visualization_nominal)
print(df_visualization_nominal['EE-119'].value_counts())
# Out:
# A-    139
# B+     83
# B      77
# A      68
# B-     48
# C      48
# C+     38
# D+     26
# C-     26
# D      11
# A+      6
# WU      1
# Name: EE-119, dtype: int64

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing
#
# Like Total No of Grade A is 139,Total No of Grade B is 77 ,Total No of Grade WU is 1,Total No of Grade D+ is 26 and so on

# %%
ax=sns.countplot(x='CS-211',data=df_visualization_nominal)
print(df_visualization_nominal['CS-211'].value_counts())
# Out:
# A-    73
# A     67
# B-    60
# D+    56
# B+    56
# B     56
# C+    55
# C-    50
# C     39
# D     33
# A+    21
# F      3
# WU     1
# W      1
# Name: CS-211, dtype: int64

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing

# %%
ax=sns.countplot(x='HS-304',data=df_visualization_nominal)
print(df_visualization_nominal['HS-304'].value_counts())
# Out:
# A-    138
# B      72
# B-     70
# B+     66
# C      58
# C+     53
# C-     33
# A      28
# D      20
# D+     19
# F       6
# A+      4
# WU      2
# W       2
# Name: HS-304, dtype: int64

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing

# %%
ax=sns.countplot(x='TC-383',data=df_visualization_nominal)
print(df_visualization_nominal['TC-383'].value_counts())
# Out:
# A     115
# A-     73
# B+     68
# B      59
# C+     44
# D+     44
# C-     42
# C      42
# B-     40
# A+     23
# D      20
# F       1
# Name: TC-383, dtype: int64

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing

# %%
ax=sns.countplot(x='MT-442',data=df_visualization_nominal)
print(df_visualization_nominal['MT-442'].value_counts())
# Out:
# A-    150
# A     130
# B+     65
# B      47
# A+     39
# B-     30
# C-     28
# C+     24
# C      24
# D      20
# D+     13
# F       1
# Name: MT-442, dtype: int64

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing

# %%
ax=sns.countplot(x='EL-332',data=df_visualization_nominal)
print(df_visualization_nominal['EL-332'].value_counts())
# Out:
# A-    105
# A      76
# B+     68
# B      67
# B-     62
# C      49
# C+     38
# C-     32
# D+     22
# D      22
# A+     20
# F       9
# WU      1
# Name: EL-332, dtype: int64

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing

# %%
ax=sns.countplot(x='CS-412',data=df_visualization_nominal)
print(df_visualization_nominal['CS-412'].value_counts())
# Out:
# A-    236
# B+     80
# A      77
# B      65
# B-     37
# C+     24
# C      19
# D+      8
# C-      7
# F       6
# D       5
# A+      4
# W       3
# Name: CS-412, dtype: int64

# %% [markdown]
# *Observation : All individual grade points frequency shown above ,how much time individual grade is appearing

# %% [markdown]
# Since we have plotted count graph for most of columns but there are 41 Nominal Data present so it will be very time consuming to draw for each column

# %% [markdown]
# * Now check Distribution of Continuous value of float type columns

# %%
df_visualization_continuous=df[['CGPA']].copy()                               #created Dataframe for continuous value
sns.displot(df_visualization_continuous['CGPA'],kde=True)

# %% [markdown]
# *Observation : Target Variable is left skewed but we do not treat Target Variable

# %% [markdown]
# # Encoding

# %% [markdown]
# As our data has lot of string/object values so convert in numerical data

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
for i in df.iloc[:,:-1]:
    df[i]=LE.fit_transform(df[i])
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %% [markdown]
# All Data converted in Numerical values

# %% [markdown]
# Statistical Summary

# %%
df.describe().T                                                     #Taken Transpose so can see all columns summary
# Out:
#            count        mean         std  min      25%      50%      75%  \
# Seat No.   571.0  285.000000  164.977776  0.0  142.500  285.000  427.500
# PH-121     571.0    3.781086    3.046895  0.0    2.000    3.000    6.000
# HS-101     571.0    5.071804    2.785317  0.0    3.000    5.000    7.000
# CY-105     571.0    2.898424    2.964737  0.0    0.000    2.000    4.500
# HS-105/12  571.0    4.241681    3.200507  0.0    2.000    4.000    7.000
# MT-111     571.0    3.896673    2.988546  0.0    2.000    4.000    6.000
# CS-105     571.0    2.838879    2.696709  0.0    0.000    2.000    4.000
# CS-106     571.0    4.122592    2.727192  0.0    2.000    4.000    5.000
# EL-102     571.0    3.959720    3.031436  0.0    2.000    3.000    6.000
# EE-119     571.0    3.886165    2.657528  0.0    2.000    3.000    6.000
# ME-107     571.0    4.779335    3.146202  0.0    2.000    5.000    8.000
# CS-107     571.0    4.068301    3.260701  0.0    1.000    4.000    7.000
# ...

# %% [markdown]
# *Observation
#
# Data is skewed for various columns and outliers also present as much diffrence in 3rd quartile and max values

# %% [markdown]
# # Check Correlation

# %%
df.corr()
# Out:
#            Seat No.    PH-121    HS-101    CY-105  HS-105/12    MT-111  \
# Seat No.   1.000000  0.068592 -0.044036 -0.263444  -0.261563 -0.200722
# PH-121     0.068592  1.000000  0.382436  0.557843   0.498561  0.468968
# HS-101    -0.044036  0.382436  1.000000  0.335074   0.473132  0.432742
# CY-105    -0.263444  0.557843  0.335074  1.000000   0.510123  0.538380
# HS-105/12 -0.261563  0.498561  0.473132  0.510123   1.000000  0.494731
# MT-111    -0.200722  0.468968  0.432742  0.538380   0.494731  1.000000
# CS-105     0.000623  0.609990  0.400713  0.578573   0.482406  0.393684
# CS-106    -0.311303  0.293963  0.312019  0.378223   0.499093  0.500729
# EL-102    -0.034679  0.423942  0.349412  0.447539   0.360304  0.555895
# EE-119     0.041367  0.579964  0.309697  0.467250   0.400303  0.409161
# ME-107     0.076715  0.533558  0.336545  0.464418   0.320137  0.471685
# CS-107    -0.068288  0.477761  0.495906  0.481277   0.540405  0.488977
# ...

# %% [markdown]
# As large no of columns present so can not see properly correlation values so draw heatmap

# %%
corr_mat=df.corr()
plt.figure(figsize=[50,50])
sns.heatmap(corr_mat,annot=True,linewidth=0.2,linecolor='Pink')
plt.title('Student Grade')
plt.show()

# %% [markdown]
# Due to large no of columns we are unable to find correlation in heatmap also then check by sorted form

# %% [markdown]
# Lets print correlation Values of independent variables with target variable in sorted form

# %%
corr_matrix=df.corr()
corr_matrix['CGPA'].sort_values(ascending=False)
# Out:
# CGPA         1.000000
# Seat No.     0.054342
# CS-414      -0.384003
# CS-312      -0.458019
# HS-205/20   -0.460525
# CS-412      -0.466512
# CS-406      -0.474419
# EF-303      -0.485478
# MT-331      -0.508428
# CS-423      -0.520968
# CS-106      -0.534995
# HS-101      -0.537170
# CS-403      -0.544543
# HS-304      -0.557912
# CS-318      -0.566393
# TC-383      -0.572329
# EE-222      -0.575335
# MT-442      -0.582592
# CS-105      -0.613169
# HS-105/12   -0.613989
# CS-107      -0.615309
# CS-211      -0.628070
# CS-421      -0.633001
# CS-419      -0.641804
# EL-102      -0.642262
# CS-212      -0.642878
# CS-203      -0.644191
# EE-119      -0.646829
# EE-217      -0.655993
# MT-222      -0.656320
# CY-105      -0.658282
# ME-107      -0.663023
# PH-121      -0.663135
# CS-301      -0.664117
# MT-224      -0.692696
# CS-302      -0.696112
# CS-306      -0.708299
# EL-332      -0.729609
# MT-111      -0.730095
# CS-215      -0.730460
# CS-214      -0.733848
# ...

# %% [markdown]
# Datas with -/+0.3 to 0.5 has weak correlation , Datas with -/+0.5 to 0.7 has moderate correlation and Datas with -/+0.7 to 1.0 have very strong correlation with target variable

# %% [markdown]
# EDA
#
# Univariate Analysis - Box Plot/Density Plot

# %%
df['PH-121'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# *No outlier is present

# %%
sns.distplot(df['PH-121'])
# Out:
# <AxesSubplot:xlabel='PH-121', ylabel='Density'>

# %% [markdown]
# Very Unsymmetrical Data, high skewness present

# %%
df['HS-105/12'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outlier present

# %%
sns.distplot(df['HS-105/12'])
# Out:
# <AxesSubplot:xlabel='HS-105/12', ylabel='Density'>

# %% [markdown]
# Very Unsymmetrical Data, high skewness present

# %%
df['EL-102'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outlier present

# %%
sns.distplot(df['EL-102'])
# Out:
# <AxesSubplot:xlabel='EL-102', ylabel='Density'>

# %% [markdown]
# Very Unsymmetrical Data, high skewness present

# %%
df['MT-222'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outlier present

# %%
sns.distplot(df['MT-222'])
# Out:
# <AxesSubplot:xlabel='MT-222', ylabel='Density'>

# %% [markdown]
# Very Unsymmetrical Data, high skewness present

# %%
df['EL-332'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No Outlier present

# %%
sns.distplot(df['EL-332'])
# Out:
# <AxesSubplot:xlabel='EL-332', ylabel='Density'>

# %% [markdown]
# Very Unsymmetrical Data, high skewness present

# %%
df['TC-383'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outlier present

# %%
sns.distplot(df['TC-383'])
# Out:
# <AxesSubplot:xlabel='TC-383', ylabel='Density'>

# %% [markdown]
# Very Unsymmetrical Data, high skewness present

# %%
df['HS-304'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Single value outlier present

# %%
sns.distplot(df['HS-304'])
# Out:
# <AxesSubplot:xlabel='HS-304', ylabel='Density'>

# %% [markdown]
# Very Unsymmetrical Data, high skewness present

# %%
df['CS-423'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outlier present

# %%
sns.distplot(df['CS-423'])
# Out:
# <AxesSubplot:xlabel='CS-423', ylabel='Density'>

# %% [markdown]
# Very Unsymmetrical Data, high skewness present

# %%
df['CS-412'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Some outliers are prsent

# %%
sns.distplot(df['CS-412'])
# Out:
# <AxesSubplot:xlabel='CS-412', ylabel='Density'>

# %% [markdown]
# Very Unsymmetrical Data, high skewness present

# %% [markdown]
# Data is uneven distributed, high skewness present in almost all columns

# %%
#Multivariate Analysis -> Scatter Plot

# %%
plt.scatter(df['PH-121'],df['CGPA'])

# %% [markdown]
# Data mainly present in points 0 to 10

# %%
plt.scatter(df['MT-331'],df['CGPA'])

# %% [markdown]
# Data mainly present in points 0 to 10

# %%
plt.scatter(df['EF-303'],df['CGPA'])

# %% [markdown]
# Data mainly present in points 2 to 9

# %%
plt.scatter(df['HS-304'],df['CGPA'])

# %% [markdown]
# Data mainly present in points 2 to 10

# %%
plt.scatter(df['HS-105/12'],df['CGPA'])

# %% [markdown]
# Data mainly present in points 0 to 10

# %%
plt.scatter(df['CS-421'],df['CGPA'])

# %% [markdown]
# Data mainly present in points 3 to 11

# %%
plt.scatter(df['CS-419'],df['CGPA'])

# %% [markdown]
# Data mainly present in points 2 to 8

# %%
plt.scatter(df['CS-423'],df['CGPA'])

# %% [markdown]
# Data mainly present in points 2 to 10

# %% [markdown]
# Since there are 43 columns so not possible to draw for every column

# %% [markdown]
# Check Data Distribution among all columns

# %%
#Multivariate Analysis

# %%
df.plot(kind='density',subplots=True,layout=(4,11),sharex=False,legend=True,figsize=(18,10))
plt.show()

# %% [markdown]
# All curves shows high skewness as not normally distributed

# %% [markdown]
# # Skewness

# %% [markdown]
# Preprocessing

# %% [markdown]
# Split data into x and y as we don't treat target variable

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %%
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %% [markdown]
# Checking Skewness

# %%
x.skew().sort_values(ascending=False)
# Out:
# CS-406       1.522703
# CS-412       1.329362
# CS-414       1.292931
# CY-105       0.982144
# CS-105       0.930769
# HS-205/20    0.897186
# MT-442       0.869952
# EE-222       0.759105
# EE-217       0.724325
# CS-210       0.723967
# CS-106       0.639845
# MT-331       0.627721
# CS-403       0.618339
# CS-302       0.601788
# EE-119       0.574880
# PH-121       0.549104
# HS-304       0.544843
# CS-423       0.526550
# CS-419       0.506748
# EL-102       0.501161
# MT-111       0.484906
# EL-332       0.459160
# CS-312       0.442525
# MT-224       0.430480
# CS-306       0.424753
# CS-301       0.415084
# CS-212       0.414872
# CS-107       0.414846
# EF-303       0.383655
# CS-318       0.356504
# TC-383       0.331652
# HS-105/12    0.324183
# CS-203       0.274205
# MT-222       0.193993
# CS-421       0.179508
# CS-215       0.163631
# CS-317       0.140692
# CS-211       0.116085
# ME-107       0.108385
# HS-101       0.053303
# CS-214       0.013129
# ...

# %% [markdown]
# Skewness allowed for +/-0.5

# %% [markdown]
# Remove Skewness - apply power transformation

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x,method='yeo-johnson')
x_new
# Out:
# array([[-2.15423096,  0.56128983,  1.67473424, ...,  1.58609347,
#         -0.1989044 , -0.30533145],
#        [-2.1279801 , -1.53065764,  1.35936594, ...,  0.91653706,
#          0.78898872,  0.18007338],
#        [-2.10544355, -1.53065764, -0.70688664, ..., -1.92838387,
#         -0.60964378, -1.83058001],
#        ...,
#        [ 1.54493129, -0.04153262, -1.98470667, ...,  0.16353993,
#         -0.60964378, -0.30533145],
#        [ 1.54960062, -1.53065764, -0.33373024, ..., -0.25875796,
#          0.48900534,  1.247191  ],
#        [ 1.55426758,  0.81556321,  1.35936594, ...,  0.16353993,
#          1.57754608,  1.7850762 ]])

# %% [markdown]
# after transformation check skewness

# %%
x=pd.DataFrame(x_new,columns=x.columns)                                        #convert transformed data into DataFrame

# %%
x.skew().sort_values(ascending=False)
# Out:
# CS-406       0.004401
# CS-412       0.004089
# CS-414      -0.005778
# CY-105      -0.013505
# HS-304      -0.034782
# CS-105      -0.036751
# CS-106      -0.039215
# CS-419      -0.044736
# MT-442      -0.045893
# HS-205/20   -0.056730
# EF-303      -0.059425
# EE-119      -0.063288
# CS-212      -0.064365
# EE-222      -0.069595
# CS-302      -0.069703
# EE-217      -0.070137
# CS-421      -0.070337
# CS-210      -0.073924
# CS-318      -0.083949
# CS-423      -0.084136
# MT-331      -0.089948
# CS-301      -0.094668
# CS-403      -0.099369
# CS-312      -0.100055
# CS-306      -0.102412
# EL-332      -0.102678
# PH-121      -0.103905
# EL-102      -0.105427
# MT-224      -0.109234
# CS-317      -0.114741
# MT-111      -0.114907
# CS-107      -0.128700
# HS-101      -0.137673
# CS-203      -0.147770
# HS-105/12   -0.149337
# TC-383      -0.156384
# CS-215      -0.166539
# MT-222      -0.172293
# CS-211      -0.182940
# CS-214      -0.187985
# ME-107      -0.188588
# ...

# %% [markdown]
# No Skewness is present

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x1=sc.fit_transform(x)
x1
# Out:
# array([[-2.15423096,  0.56128983,  1.67473424, ...,  1.58609347,
#         -0.1989044 , -0.30533145],
#        [-2.1279801 , -1.53065764,  1.35936594, ...,  0.91653706,
#          0.78898872,  0.18007338],
#        [-2.10544355, -1.53065764, -0.70688664, ..., -1.92838387,
#         -0.60964378, -1.83058001],
#        ...,
#        [ 1.54493129, -0.04153262, -1.98470667, ...,  0.16353993,
#         -0.60964378, -0.30533145],
#        [ 1.54960062, -1.53065764, -0.33373024, ..., -0.25875796,
#          0.48900534,  1.247191  ],
#        [ 1.55426758,  0.81556321,  1.35936594, ...,  0.16353993,
#          1.57754608,  1.7850762 ]])

# %%
x=pd.DataFrame(x1,columns=x.columns)

# %% [markdown]
# # Multicollinearity Check VIF Technique

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
x
# Out:
#      Seat No.    PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# 0   -2.154231  0.561290  1.674734  1.418591   0.647755  1.261253  1.838873
# 1   -2.127980 -1.530658  1.359366  1.676105   1.331851  0.511748  1.156812
# 2   -2.105444 -1.530658 -0.706887 -1.274197   0.386642  0.215952 -1.368972
# 3   -2.085024  1.463304  0.708810  1.676105   1.331851  1.478929 -0.020426
# 4   -2.066047 -0.417037 -1.099218  0.043625   0.101867 -1.580537 -1.368972
# ..        ...       ...       ...       ...        ...       ...       ...
# 566  1.535585 -0.041533 -1.984707 -1.274197  -0.574628 -0.958828 -1.368972
# 567  1.540260 -0.882125 -1.984707 -1.274197  -1.570415 -1.580537 -1.368972
# 568  1.544931 -0.041533 -1.984707  0.043625   0.101867 -1.580537 -1.368972
# 569  1.549601 -1.530658 -0.333730  1.553548  -1.570415  1.478929  1.838873
# 570  1.554268  0.815563  1.359366  1.553548   0.647755  0.781051  1.838873
#
# ...

# %%
x.shape
# Out:
# (571, 42)

# %%
x.shape[1]
# Out:
# 42

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["features"]=x.columns
    print(vif)
    
vif_calc()
# Out:
#     VIF Factor   features
# 0     4.026645   Seat No.
# 1     2.620961     PH-121
# 2     1.809000     HS-101
# 3     2.492485     CY-105
# 4     2.295349  HS-105/12
# 5     2.500785     MT-111
# 6     2.206400     CS-105
# 7     1.831170     CS-106
# 8     1.929667     EL-102
# 9     2.179665     EE-119
# 10    2.344590     ME-107
# 11    2.248136     CS-107
# 12    1.678313  HS-205/20
# 13    2.255036     MT-222
# 14    2.187108     EE-222
# 15    2.843790     MT-224
# 16    3.119355     CS-210
# 17    2.791289     CS-211
# 18    2.597560     CS-203
# 19    2.792397     CS-214
# 20    2.365832     EE-217
# 21    2.617716     CS-212
# 22    3.056807     CS-215
# 23    2.112486     MT-331
# 24    2.192705     EF-303
# 25    2.383692     HS-304
# 26    3.122029     CS-301
# 27    2.768354     CS-302
# 28    2.854230     TC-383
# 29    1.851832     MT-442
# 30    3.210695     EL-332
# 31    2.515284     CS-318
# 32    3.573741     CS-306
# 33    3.051260     CS-312
# ...

# %% [markdown]
# All Columns have VIF value <5 so NO Multicollinearity is there

# %% [markdown]
# # Outliers detection

# %%
from scipy.stats import zscore
import numpy as np

# %%
z=np.abs(zscore(x))
z
# Out:
#      Seat No.    PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# 0    2.154231  0.561290  1.674734  1.418591   0.647755  1.261253  1.838873
# 1    2.127980  1.530658  1.359366  1.676105   1.331851  0.511748  1.156812
# 2    2.105444  1.530658  0.706887  1.274197   0.386642  0.215952  1.368972
# 3    2.085024  1.463304  0.708810  1.676105   1.331851  1.478929  0.020426
# 4    2.066047  0.417037  1.099218  0.043625   0.101867  1.580537  1.368972
# ..        ...       ...       ...       ...        ...       ...       ...
# 566  1.535585  0.041533  1.984707  1.274197   0.574628  0.958828  1.368972
# 567  1.540260  0.882125  1.984707  1.274197   1.570415  1.580537  1.368972
# 568  1.544931  0.041533  1.984707  0.043625   0.101867  1.580537  1.368972
# 569  1.549601  1.530658  0.333730  1.553548   1.570415  1.478929  1.838873
# 570  1.554268  0.815563  1.359366  1.553548   0.647755  0.781051  1.838873
#
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# *Observation : This shows no outliers is there so no need to remove oulier and no data loss here

# %% [markdown]
# # Scaling data using Min-MaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
x=mms.fit_transform(x)
x
# Out:
# array([[0.        , 0.59282791, 0.92196585, ..., 0.79608778, 0.40717973,
#         0.34076191],
#        [0.00707857, 0.        , 0.84251141, ..., 0.64442208, 0.66901721,
#         0.44920815],
#        [0.01315557, 0.        , 0.32193618, ..., 0.        , 0.29831476,
#         0.        ],
#        ...,
#        [0.99748246, 0.42199668, 0.        , ..., 0.47385566, 0.29831476,
#         0.34076191],
#        [0.99874155, 0.        , 0.41594985, ..., 0.37819814, 0.58950771,
#         0.68761718],
#        [1.        , 0.66488534, 0.84251141, ..., 0.47385566, 0.87802147,
#         0.80778827]])

# %%
x=pd.DataFrame(x)
x
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.000000  0.592828  0.921966  0.850478  0.636270  0.779106  1.000000
# 1    0.007079  0.000000  0.842511  0.931810  0.832499  0.573621  0.787377
# 2    0.013156  0.000000  0.321936  0.000000  0.561371  0.492526  0.000000
# 3    0.018662  0.848446  0.678609  0.931810  0.832499  0.838784  0.420390
# 4    0.023779  0.315584  0.223091  0.416215  0.479685  0.000000  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 566  0.994962  0.421997  0.000000  0.000000  0.285636  0.170448  0.000000
# 567  0.996223  0.183785  0.000000  0.000000  0.000000  0.000000  0.000000
# 568  0.997482  0.421997  0.000000  0.416215  0.479685  0.000000  0.000000
# 569  0.998742  0.000000  0.415950  0.893102  0.000000  0.838784  1.000000
# 570  1.000000  0.664885  0.842511  0.893102  0.636270  0.647454  1.000000
#
#            7         8         9   ...        32        33        34  \
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# Best Random State

# %%
maxr2_score=0                            #maximum r2_score
maxRS=0                             #best random state for which max r2 score is achieved

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)                                #fitting the data will train your model
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)   
    r2=r2_score(y_test,pred_test)
    print('At random state',i,"Training Accuracy is",r2_score(y_train,pred_train)*100) 
    print('At random state',i,"Testing Accuracy is",r2_score(y_test,pred_test)*100) 
    
    if r2>maxr2_score:
        maxr2_score=r2
        maxRS=i
        print('max_r2',maxr2_score,'max_random_state',i)
# Out:
# At random state 1 Training Accuracy is 90.26697164075944
# At random state 1 Testing Accuracy is 93.07066550652213
# max_r2 0.9307066550652213 max_random_state 1
# At random state 2 Training Accuracy is 90.65833698056498
# At random state 2 Testing Accuracy is 91.28643589327115
# At random state 3 Training Accuracy is 90.19254851850926
# At random state 3 Testing Accuracy is 92.64588285880578
# At random state 4 Training Accuracy is 90.40753118431897
# At random state 4 Testing Accuracy is 91.86775112077538
# At random state 5 Training Accuracy is 90.78327136722326
# At random state 5 Testing Accuracy is 90.03046171479868
# At random state 6 Training Accuracy is 90.2749099031166
# At random state 6 Testing Accuracy is 93.37892221041916
# max_r2 0.9337892221041917 max_random_state 6
# At random state 7 Training Accuracy is 90.33386569198423
# At random state 7 Testing Accuracy is 93.32685867095533
# At random state 8 Training Accuracy is 91.00635249224493
# ...

# %%
print("Best r2_score is",maxr2_score,"on Random_state",maxRS)
# Out:
# Best r2_score is 0.9583167047397847 on Random_state 72

# %% [markdown]
# Best Random_State found is 72.We will create our train_test_split using this random_state

# %% [markdown]
# # Train_Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=72)

# %%
x_train.shape
# Out:
# (456, 42)

# %%
x_test.shape
# Out:
# (115, 42)

# %%
y_train.shape
# Out:
# (456,)

# %%
y_test.shape
# Out:
# (115,)

# %% [markdown]
# Metrics Imported

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

lr.fit(x_train,y_train)                                #fitting the data will train your model
pred_test=lr.predict(x_test)                           #predicted variable for testing
pred_train=lr.predict(x_train)

print('Testing Accuracy is',r2_score(y_test,pred_test))
print('Training Accuracy is',r2_score(y_train,pred_train))
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_test))
print('Mean squared Error:',mean_squared_error(y_test,pred_test))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# Testing Accuracy is 0.9583167047397847
# Training Accuracy is 0.8953760192788582
# Error:
# Mean Absolute Error: 0.1028993150088058
# Mean squared Error: 0.01674642023436639
# Root Mean squared Error: 0.12940796047525974

# %% [markdown]
# # Cross Validation for lr

# %%
from sklearn.model_selection import cross_val_score
cr_1=cross_val_score(lr,x,y,cv=10)
print("Cross Validation Score of Linear Regression model:-",cr_1.mean())
print("diff between r2 score and cross validation score is -",r2_score(y_test,pred_test)-cr_1.mean())
# Out:
# Cross Validation Score of Linear Regression model:- 0.8810074938394676
# diff between r2 score and cross validation score is - 0.07730921090031706

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# Best Fit Line is covering most of datapoints which shows good fit of our model

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Lasso,Ridge                 #Alpha Value should be same for all regression

# %% [markdown]
# # Lasso Regression

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
print((ls_score_training)*100)
# Out:
# 89.53460173586947

# %%
lss=r2_score(y_test,pred_ls)

# %%
print('r2_score is:',lss*100)
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_ls))
print('Mean squared Error:',mean_squared_error(y_test,pred_ls))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# r2_score is: 95.91206464843033
# Error:
# Mean Absolute Error: 0.10195793616219229
# Mean squared Error: 0.016423433622736662
# Root Mean squared Error: 0.12815394501433292

# %% [markdown]
# Cross Validation for Lasso Regression

# %%
cr_2=cross_val_score(ls,x,y,cv=10)
print("Cross Validation Score of Lasso Regression model:-",cr_2.mean())
print("diff between r2 score and cross validation score is -",r2_score(y_test,pred_test)-cr_2.mean())
# Out:
# Cross Validation Score of Lasso Regression model:- 0.8814937518484547
# diff between r2 score and cross validation score is - 0.07682295289133001

# %% [markdown]
# # Ridge Regression

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
rd_score_training=rd.score(x_train,y_train)
pred_rd=rd.predict(x_test)
print((rd_score_training)*100)
# Out:
# 89.5376019276944

# %%
rdg=r2_score(y_test,pred_rd)

# %%
print('r2_score is:',rdg*100)
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_rd))
print('Mean squared Error:',mean_squared_error(y_test,pred_rd))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# r2_score is: 95.83169709252141
# Error:
# Mean Absolute Error: 0.10289905820865515
# Mean squared Error: 0.01674631329337161
# Root Mean squared Error: 0.12940754728133755

# %% [markdown]
# Cross Validation for Ridge Regression

# %%
cr_3=cross_val_score(rd,x,y,cv=10)
print("Cross Validation Score of Ridge Regression model:-",cr_3.mean())
print("diff between r2 score and cross validation score is -",r2_score(y_test,pred_test)-cr_3.mean())
# Out:
# Cross Validation Score of Ridge Regression model:- 0.8810077261554359
# diff between r2 score and cross validation score is - 0.07730897858434882

# %% [markdown]
# # Ensemble Technique

# %% [markdown]
# To make our model more perfect we try another method RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_rf=rf.predict(x_test)

# %%
rfs=r2_score(y_test,pred_rf)

# %%
print('r2_score is:',rfs*100)
print('Error:')
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_rf))
print('Mean squared Error:',mean_squared_error(y_test,pred_rf))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,pred_rf)))
# Out:
# r2_score is: 94.44620006582069
# Error:
# Mean Absolute Error: 0.1083593913043478
# Mean squared Error: 0.022312599571304343
# Root Mean squared Error: 0.1493740257585111

# %%
cr_4=cross_val_score(rf,x,y,cv=10)
print("Cross Validation Score of Random Forest Regression model:-",cr_4.mean())
print("diff between r2 score and cross validation score is -",r2_score(y_test,pred_test)-cr_4.mean())
# Out:
# Cross Validation Score of Random Forest Regression model:- 0.9155153711858123
# diff between r2 score and cross validation score is - 0.04280133355397242

# %% [markdown]
# As we can observe diff between r2 score and cross validation score is - 0.04280 is least in Random Forest Regressor so it is best model. We will do Hyper Tuning Parameter on this model

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf=RandomForestRegressor()
parameters={'criterion':['mse','mae'],
           'max_features':['auto','sqrt','log2'],
           'n_estimators':[100,200,300,400],
           'random_state':[7,8,9,10]}

# %%
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

# %% [markdown]
# As on running no output shows for best parametrs so if we take best parameters as {'criterion':'mae','max_features':'sqrt','n_estimators':300,'random_state':7}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='sqrt',n_estimators=300,random_state=7)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_rf=rf.predict(x_test)

# %%
rfs=r2_score(y_test,pred_rf)

# %%
print('r2_score is:',rfs*100)
# Out:
# r2_score is: 97.02978595301501

# %% [markdown]
# We save it as Final Model as r2_score is 97% which shows model is well performed

# %%
import pickle
filename='studentgrade.pkl'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# Prediction

# %%
conclusion=pd.DataFrame([rf.predict(x_test)[:],pred_rf[:]],index=["Predicted","Original"])
conclusion
# Out:
#                 0        1         2         3         4         5    \
# Predicted  2.284895  3.45541  3.118915  2.390827  2.488635  3.683923
# Original   2.284895  3.45541  3.118915  2.390827  2.488635  3.683923
#
#                 6        7         8        9    ...       105       106  \
# Predicted  3.289427  3.86905  3.407308  3.83748  ...  2.051885  2.875053
# Original   3.289427  3.86905  3.407308  3.83748  ...  2.051885  2.875053
#
#                 107       108      109       110      111       112       113  \
# Predicted  3.253063  3.524693  3.33901  3.255937  2.40275  2.130187  2.458028
# Original   3.253063  3.524693  3.33901  3.255937  2.40275  2.130187  2.458028
#
#                 114
# Predicted  3.558567
# Original   3.558567
#
# [2 rows x 115 columns]
